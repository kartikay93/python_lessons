# %% [markdown]
# ## Exception handling

# %%
a = b
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = b
#       2 print(b)
#
# NameError: name 'b' is not defined

# %%
# Exception try, except block

try:
    a=b
except:
    print("The variable has not benn assigned")
# Out:
# The variable has not benn assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = 10/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 10/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator other than 0")
# Out:
# division by zero
# Please enter the denominator other than 0

# %%
try:
    result = 1/5
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator other than 0")
except Exception as ex1:         # Main exception block
    print(ex1)
    print("Main exception got caught here")
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
except ValueError:
    print("Please enter a valid number")
except ZeroDivisionError:
    print("Please enter a denominator other than 0")
except Exception as ex:
    print(ex)
# Out:
# Please enter a valid number

# %%
# try, except, else block

try:
    num = int(input("Enter a number: "))
    result = 10/num
except ValueError:
    print("Please enter a valid number")
except ZeroDivisionError:
    print("You can't divide by 0")
except Exception as ex:
    print(ex)
else:
    print("The result is: ", result)
# Out:
# The result is:  0.29411764705882354

# %%
# try, except, else, finally block

try:
    num = int(input("Enter a number: "))
    result = 10/num
except ValueError:
    print("Please enter a valid number")
except ZeroDivisionError:
    print("You can't divide by 0")
except Exception as ex:
    print(ex)
else:
    print(f"The result is: {result}")
finally:
    print("Execution completed")
    print("This block will always execute, whether an exception occurs or not")
# Out:
# The result is: 0.17857142857142858
# Execution completed
# This block will always execute, whether an exception occurs or not

# %%
try:
    file=open('example.txt', 'r')
    content = file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("The file does not exist. Please check the file name and try again.")
except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() and not file.closed:
        file.close()
        print("File closed.")
# Out:
# The file does not exist. Please check the file name and try again.

# %%
try:
    file=open('example.txt', 'r')
    content = file.read()
    a=b
    #print(content)

except FileNotFoundError:
    print("The file does not exist. Please check the file name and try again.")
except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() or not file.closed:
        print(content)
        file.close()
        print("File closed.")
# Out:
# name 'b' is not defined
# hellow
#
# File closed.
