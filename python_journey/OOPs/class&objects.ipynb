# %% [markdown]
# ## Class and objects

# %%
class Car:
    pass

audi = Car()
bmw = Car()

print(audi)
print(type(audi))
# Out:
# <__main__.Car object at 0x00000168DBD47770>
# <class '__main__.Car'>

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
bmw.doors = 4
print(bmw.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 bmw.doors = 4
# ----> 2 print(bmw.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
## Instance variable and methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

dog1 = Dog("Buddy", 3)
print(dog1.name)
# Out:
# Buddy

# %%
## Defining methods in a class
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        return f"{self.name} says woof."
    
dog1 = Dog("Buddy", 3)
print(dog1.bark())
# Out:
# Buddy says woof.

# %%
## Modeling a bank account

## define a class for bank account 
class BankAccount:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited {amount}. New balance is {self.balance}.")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance is {self.balance}.")
    
    def get_balance(self):
        return self.balance


account1 = BankAccount("Alice", 10000)
account1.deposit(500)
account1.withdraw(2080)
# Out:
# Deposited 500. New balance is 10500.
# Withdrew 2080. New balance is 8420.
