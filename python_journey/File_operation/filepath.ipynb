# %% [markdown]
# ## File Path

# %%
import os
cwd = os.getcwd()
print(f"Current working directory: {cwd}")
# Out:
# Current working directory: c:\Users\Kartikay\Documents\python_lessons\python_journey\File_operation

# %%
# create a new directory
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'package' created.

# %%
# listing all files and directories in the current working directory
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.txt', 'exapmle.bin', 'fileoperation.ipynb', 'filepath.ipynb', 'package']

# %%
# joining paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(f"Full path: {full_path}")
# Out:
# Full path: folder\file.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(f"Full path: {full_path}")
# Out:
# Full path: c:\Users\Kartikay\Documents\python_lessons\python_journey\File_operation\folder\file.txt

# %%
path = "example1.txt" 
if os.path.exists(path):
    print(f"The path '{path}' exists.")
else:
    print(f"The path '{path}' does not exist.")
# Out:
# The path 'example1.txt' does not exist.

# %%
# checking if a path is a file or directory
import os
path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'example.txt' is a file.

# %%
# getting the absolute path of a file
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(f"Absolute path of '{relative_path}': {absolute_path}")
# Out:
# Absolute path of 'example.txt': c:\Users\Kartikay\Documents\python_lessons\python_journey\File_operation\example.txt
