# %%
import array
arr = array.array('i',[1,2,3,4,5])
print(arr)

# %%
import math
print(math.sqrt(64))
print(math.sqrt(5))
print(math.pi)

# %%
import random
print(random.randint(1,12))
print(random.choice(['apple','mango','banana','strawberry','carrot']))

# %%
import os
print(os.getcwd())

# %%
os.mkdir('test_dir')

# %%
filename = "myfile.txt"
flags = os.O_WRONLY | os.O_CREAT

file_descripter = os.open(filename,flags, 0o666)
print(file_descripter)
os.close(file_descripter)

# %%
with open("testfile.txt", 'w') as f:
    pass

# %%
with open("myfile.txt",'a') as file:
    file.write("This text will be appended.\n")

# %%
import shutil
shutil.copyfile('myfile.txt','testfile.txt')

# %%
#Data Serialization
import json
data = {'name':'krish','age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))

# %%
import csv
with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Krish', 32])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

# %%
from datetime import datetime,timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)

# %%
import time
print(time.time())
time.sleep(3)
print(time.time())

# %%
# Regular expression
import re

pattern = r'\d+'
text = 'There are 134 days left'
match = re.search(pattern,text)
print(match.group())

# %%
nums = [1,2,3,4,5,5]
nums = list(set(nums))
print(type(nums))
# Out:
# <class 'list'>

# %%
lst = [1,2,3,4,0,-4,-2,-1,-3,-5]
res = set()
lst.sort()
for i in range(len(lst)):
    for j in range(i+1,len(lst)):
        if -(lst[i]+lst[j]) in lst:
            z = lst.index(-(lst[i]+lst[j]))
            res.add((lst[i],lst[z],lst[j]))
x = [list(triplet) for triplet in res]
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 9
#       5     for j in range(i+1,len(lst)):
#       6         if -(lst[i]+lst[j]) in lst:
#       7             z = lst.index(-(lst[i]+lst[j]))
#       8             res.add((lst[i],lst[z],lst[j]))
# ----> 9 x = [list(triplet) for triplet in res]
#      10 print(x)
#      11
#
# TypeError: 'list' object is not callable
